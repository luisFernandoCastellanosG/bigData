# %% [markdown]
# # Proyecto de BigData
# ---
# * Nombre: xxxxx
# * Código: xxxxx
# * correo: xxx@xxxx
# * asignatura: xxxxx

# %% [markdown]
# #Instalar librerias especiales

# %%
# !apt update
# !apt install -y python3-pip
# !pip3 install pymongo        #libreria especial ()

# %%
# !sudo apt-get update
# !sudo apt-get install -y mongodb-org

# %% [markdown]
# # 2.Trabajaremos con Google Drive

# %%
# habilitamos drive de google desde colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 3. Cargue de la configuración basica del proyecto
# ---
# *   credenciales
# *   constantes (rutas de api's, carpetas, etc)

# %%
url_project='/content/drive/MyDrive/UniversidadCentral/Maestría_en_Analítica_de_Datos/Bigdata/Ejercicios_de_clase/BigData_project/'

# %%
#  importar librerias (archivo python)  del proyecto
import sys
sys.path.append(url_project+'Helpers')
sys.path.append(url_project+'models')
import mongoDb

# %%
#Importando libreria con las configuraciones del proyecto
from config import Config
print(' constante RUTA_DATOS=[',Config.RUTA_DATOS,']')
# Out:
#  constante RUTA_DATOS=[ /home/usuario/datos ]
